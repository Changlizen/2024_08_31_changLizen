# %%
import random
import time

for i in range(100):
    print(random.randint(1,10))
    time.sleep(1)

# %%
import requests
r = requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41952726323","type":"PushEvent","actor":{"id":145564,"login":"JAORMX","display_login":"JAORMX","gravatar_id":"","url":"https://api.github.com/users/JAORMX","avatar_url":"https://avatars.githubusercontent.com/u/145564?"},"repo":{"id":624056558,"name":"stacklok/minder","url":"https://api.github.com/repos/stacklok/minder"},"payload":{"repository_id":624056558,"push_id":20251925627,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"21e66aa5521c19869c085af0cdf5c7b28aa4481c","before":"f48f6ed2051685a27583cb18c828bb405b415c81","commits":[{"sha":"21e66aa5521c19869c085af0cdf5c7b28aa4481c","author":{"email":"49699333+dependabot[bot]@users.noreply.github.com","name":"dependabot[bot]"},"message":"build(deps): bump sigs.k8s.io/release-utils from 0.8.4 to 0.8.5 (#4487)\\n\\nBumps [sigs.k8s.io/release-utils](https://github.com/kubernetes-sigs/release-utils) from 0.8.4 to 0.8.5.\\r\\n- [Release notes](https://github.com/kubernetes-sigs/release-utils/releases)\\r\\n- [Commits](https:
# ...
