# %%
import random
import time

for i in range(100):
    print(random.randint(1,10))
    time.sleep(1)

# %%
import requests
r = requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41926826201","type":"PushEvent","actor":{"id":119986792,"login":"Atticuszz","display_login":"Atticuszz","gravatar_id":"","url":"https://api.github.com/users/Atticuszz","avatar_url":"https://avatars.githubusercontent.com/u/119986792?"},"repo":{"id":856841236,"name":"Atticuszz/Spark","url":"https://api.github.com/repos/Atticuszz/Spark"},"payload":{"repository_id":856841236,"push_id":20235335711,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"b844e5d6d624e16a217305dec66d2cad32ae9fa6","before":"55e722e6aca6fe7dda5e0c28c6bcddc946b42066","commits":[{"sha":"b844e5d6d624e16a217305dec66d2cad32ae9fa6","author":{"email":"1831768457@qq.com","name":"Atticus Zhou"},"message":"2024-09-14 15:50:12: ...\\n\\nAffected files:\\n.obsidian/workspace-mobile.json\\ndocs/Daily/writing/2024-9.md\\ndocs/Learning/CS/VCS/git.md","distinct":true,"url":"https://api.github.com/repos/Atticuszz/Spark/commits/b844e5d6d624e16a217305dec66d2cad32ae9fa6"}]},"public":true,"created_at":"2024-09-14T07:50
# ...
