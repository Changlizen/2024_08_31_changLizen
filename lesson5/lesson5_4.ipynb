# %%
import random
import time

for i in range(100):
    print(random.randint(1,10))
    time.sleep(1)

# %%
import requests
r = requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41949767558","type":"ReleaseEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":857394500,"name":"Kirya23/Fall_semestr","url":"https://api.github.com/repos/Kirya23/Fall_semestr"},"payload":{"action":"published","release":{"url":"https://api.github.com/repos/Kirya23/Fall_semestr/releases/175156744","assets_url":"https://api.github.com/repos/Kirya23/Fall_semestr/releases/175156744/assets","upload_url":"https://uploads.github.com/repos/Kirya23/Fall_semestr/releases/175156744/assets{?name,label}","html_url":"https://github.com/Kirya23/Fall_semestr/releases/tag/25-mac","id":175156744,"author":{"login":"github-actions[bot]","id":41898282,"node_id":"MDM6Qm90NDE4OTgyODI=","avatar_url":"https://avatars.githubusercontent.com/in/15368?v=4","gravatar_id":"","url":"https://api.github.com/users/git
# ...
