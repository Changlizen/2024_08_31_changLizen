# %%
import random
import time

for i in range(100):
    print(random.randint(1,10))
    time.sleep(1)

# %%
import requests
r = requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41952082110","type":"PushEvent","actor":{"id":141381306,"login":"DileepKumarIrri","display_login":"DileepKumarIrri","gravatar_id":"","url":"https://api.github.com/users/DileepKumarIrri","avatar_url":"https://avatars.githubusercontent.com/u/141381306?"},"repo":{"id":749879295,"name":"DileepKumarIrri/Profile-Views","url":"https://api.github.com/repos/DileepKumarIrri/Profile-Views"},"payload":{"repository_id":749879295,"push_id":20251607648,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"546641706dfb5b852dd969c5c2c9263355cfcb0d","before":"f1ff4ac728518f91eca00c108e6c2417b130bc06","commits":[{"sha":"546641706dfb5b852dd969c5c2c9263355cfcb0d","author":{"email":"41898282+github-actions[bot]@users.noreply.github.com","name":"github-actions[bot]"},"message":"Update views","distinct":true,"url":"https://api.github.com/repos/DileepKumarIrri/Profile-Views/commits/546641706dfb5b852dd969c5c2c9263355cfcb0d"}]},"public":true,"created_at":"2024-09-16T06:28:03Z"},{"id":"419520821
# ...
