# %%
import requests
r = requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41954664461","type":"PullRequestEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":475991571,"name":"aluzzardi/dagger","url":"https://api.github.com/repos/aluzzardi/dagger"},"payload":{"action":"closed","number":593,"pull_request":{"url":"https://api.github.com/repos/aluzzardi/dagger/pulls/593","id":2060343445,"node_id":"PR_kwDOHF8OE856zliV","html_url":"https://github.com/aluzzardi/dagger/pull/593","diff_url":"https://github.com/aluzzardi/dagger/pull/593.diff","patch_url":"https://github.com/aluzzardi/dagger/pull/593.patch","issue_url":"https://api.github.com/repos/aluzzardi/dagger/issues/593","number":593,"state":"closed","locked":false,"title":"chore(deps): bump the sdk-python group across 1 directory with 2 updates","user":{"login":"dependabot[bot]","id":49699333,"node_id":"MDM6Qm90NDk2OTkzMz
# ...
